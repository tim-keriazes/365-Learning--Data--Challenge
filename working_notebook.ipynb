# %% [markdown]
# Imports/Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from scipy import stats

# %% [markdown]
# ### Import 11 csv files
# - manual import of csv files from the database
# - examine components

# %%
['365_course_info.csv','365_course_ratings.csv','365_exam_info.csv','365_quiz_info.csv','365_student_engagement.csv',
'365_student_exams.csv','365_student_hub_questions.csv','365_student_info.csv','365_student_learning.csv','365_student_purchases.csv'
, '365_student_quizzes.csv']

# %%
# df = pd.read_csv(r'Path where the CSV file is stored\File name.csv')
# print(df)

# %%
course_info=pd.read_csv(r'365_course_info.csv')
course_ratings=pd.read_csv(r'365_course_ratings.csv')
exam_info=pd.read_csv(r'365_exam_info.csv')
quiz_info=pd.read_csv(r'365_quiz_info.csv')
student_engagement=pd.read_csv(r'365_student_engagement.csv')
student_exams=pd.read_csv(r'365_student_exams.csv')
student_hub_questions=pd.read_csv(r'365_student_hub_questions.csv')
student_info=pd.read_csv(r'365_student_info.csv')
student_learning=pd.read_csv(r'365_student_learning.csv')
student_purchases=pd.read_csv(r'365_student_purchases.csv')
student_quizzes=pd.read_csv(r'365_student_quizzes.csv')

# %%
course_info.head()
# Out:
#    course_id                                       course_title
# 0          2                            Introduction to Tableau
# 1          3  The Complete Data Visualization Course with Py...
# 2          4                      Introduction to R Programming
# 3          5                      Data Preprocessing with NumPy
# 4          7              Introduction to Data and Data Science

# %%
# import necessary libraries
import pandas as pd
import os
import glob
  
  
# use glob to get all the csv files 
# in the folder
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
  
  
# loop over the list of csv files
for f in csv_files:
      
    # read the csv file
    df = pd.read_csv(f)
      
    # print the location and filename
    print('Location:', f)
    print('File Name:', f.split("\\")[-1])
      
    # print the content
    print('Content:')
    display(df)
    print()
# Out:
# Location: C:\Users\Timmy\365_learning_challenge\365_database\365_course_info.csv
# File Name: 365_course_info.csv
# Content:
#     course_id                                       course_title
# 0           2                            Introduction to Tableau
# 1           3  The Complete Data Visualization Course with Py...
# 2           4                      Introduction to R Programming
# 3           5                      Data Preprocessing with NumPy
# 4           7              Introduction to Data and Data Science
# 5          11        Data Cleaning and Preprocessing with pandas
# 6          12                 Introduction to Business Analytics
# 7          13              Data Analysis with Excel Pivot Tables
# 8          14                                                SQL
# 9          15                     Credit Risk Modeling in Python
# 10         16                         Python Programmer Bootcamp
# 11         19                             SQL + Tableau + Python
# ...

# %%
# assign dataset names
list_of_names = ['365_course_info','365_course_ratings','365_exam_info','365_quiz_info','365_student_engagement',
'365_student_exams','365_student_hub_questions','365_student_info','365_student_learning','365_student_purchases'
, '365_student_quizzes']
 
# create empty list
dataframes_list = []
 
# append datasets into the list
for i in range(len(list_of_names)):
    temp_df = pd.read_csv("./"+list_of_names[i]+".csv")
    dataframes_list.append(temp_df)

# %%
dataframes_list
# Out:
# [    course_id                                       course_title
#  0           2                            Introduction to Tableau
#  1           3  The Complete Data Visualization Course with Py...
#  2           4                      Introduction to R Programming
#  3           5                      Data Preprocessing with NumPy
#  4           7              Introduction to Data and Data Science
#  5          11        Data Cleaning and Preprocessing with pandas
#  6          12                 Introduction to Business Analytics
#  7          13              Data Analysis with Excel Pivot Tables
#  8          14                                                SQL
#  9          15                     Credit Risk Modeling in Python
#  10         16                         Python Programmer Bootcamp
#  11         19                             SQL + Tableau + Python
#  12         20                            Introduction to Jupyter
# ...

# %%
dataframes_list.count
# Out:
# <function list.count(value, /)>
